# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('US_Accidents_June.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3513617 entries, 0 to 3513616
# Data columns (total 49 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Source                 object
#  2   TMC                    float64
#  3   Severity               int64
#  4   Start_Time             object
#  5   End_Time               object
#  6   Start_Lat              float64
#  7   Start_Lng              float64
#  8   End_Lat                float64
#  9   End_Lng                float64
#  10  Distance(mi)           float64
#  11  Description            object
#  12  Number                 float64
#  13  Street                 object
#  14  Side                   object
#  15  City                   object
#  16  County                 object
#  17  State                  object
#  18  Zipcode                object
#  19  Country                object
#  20  Timezone               object
#  21  Airport_Code           object
#  22  Weather_Timestamp      object
#  23  Temperature(F)         float64
#  24  Wind_Chill(F)          float64
#  25  Humidity(%)            float64
#  26  Pressure(in)           float64
#  27  Visibility(mi)         float64
#  28  Wind_Direction         object
#  29  Wind_Speed(mph)        float64
#  30  Precipitation(in)      float64
#  31  Weather_Condition      object
#  32  Amenity                bool
#  33  Bump                   bool
#  34  Crossing               bool
#  35  Give_Way               bool
#  36  Junction               bool
#  37  No_Exit                bool
#  38  Railway                bool
#  39  Roundabout             bool
#  40  Station                bool
#  41  Stop                   bool
#  42  Traffic_Calming        bool
#  43  Traffic_Signal         bool
#  44  Turning_Loop           bool
#  45  Sunrise_Sunset         object
#  46  Civil_Twilight         object
#  47  Nautical_Twilight      object
#  48  Astronomical_Twilight  object
# dtypes: bool(13), float64(14), int64(1), object(21)
# memory usage: 1008.6+ MB

# %%
(df.isnull().sum()/df.shape[0])*100
# Out:
# ID                        0.000000
# Source                    0.000000
# TMC                      29.451104
# Severity                  0.000000
# Start_Time                0.000000
# End_Time                  0.000000
# Start_Lat                 0.000000
# Start_Lng                 0.000000
# End_Lat                  70.548896
# End_Lng                  70.548896
# Distance(mi)              0.000000
# Description               0.000028
# Number                   64.402694
# Street                    0.000000
# Side                      0.000000
# City                      0.003188
# County                    0.000000
# State                     0.000000
# Zipcode                   0.030424
# Country                   0.000000
# Timezone                  0.110428
# Airport_Code              0.192337
# Weather_Timestamp         1.233003
# Temperature(F)            1.870779
# Wind_Chill(F)            53.171675
# Humidity(%)               1.983341
# Pressure(in)              1.590441
# Visibility(mi)            2.158915
# Wind_Direction            1.675595
# Wind_Speed(mph)          12.938490
# Precipitation(in)        57.657793
# Weather_Condition         2.166941
# Amenity                   0.000000
# Bump                      0.000000
# Crossing                  0.000000
# Give_Way                  0.000000
# Junction                  0.000000
# No_Exit                   0.000000
# Railway                   0.000000
# Roundabout                0.000000
# Station                   0.000000
# Stop                      0.000000
# Traffic_Calming           0.000000
# Traffic_Signal            0.000000
# Turning_Loop              0.000000
# Sunrise_Sunset            0.003273
# Civil_Twilight            0.003273
# Nautical_Twilight         0.003273
# Astronomical_Twilight     0.003273
# dtype: float64

# %%
#TMC, End_Lat , End_Lng, Number, Wind_Chill, Wind_Speed, Precipitation have more missing values

# %%
df['TMC'].value_counts()
# Out:
# 201.0    2080341
# 241.0     249852
# 245.0      40338
# 229.0      22932
# 203.0      17639
# 222.0      13154
# 244.0      12185
# 406.0      11109
# 246.0       7118
# 343.0       6930
# 202.0       6298
# 247.0       4775
# 236.0       2121
# 206.0       1274
# 248.0       1025
# 339.0        920
# 341.0        592
# 336.0         89
# 200.0         66
# 239.0         54
# 351.0          6
# Name: TMC, dtype: int64

# %%
#sns.heatmap(df.isnull(),cbar = False, cmap = 'inferno')

# %%
import datetime as dt

# %%
df.columns
# Out:
# Index(['ID', 'Source', 'TMC', 'Severity', 'Start_Time', 'End_Time',
#        'Start_Lat', 'Start_Lng', 'End_Lat', 'End_Lng', 'Distance(mi)',
#        'Description', 'Number', 'Street', 'Side', 'City', 'County', 'State',
#        'Zipcode', 'Country', 'Timezone', 'Airport_Code', 'Weather_Timestamp',
#        'Temperature(F)', 'Wind_Chill(F)', 'Humidity(%)', 'Pressure(in)',
#        'Visibility(mi)', 'Wind_Direction', 'Wind_Speed(mph)',
#        'Precipitation(in)', 'Weather_Condition', 'Amenity', 'Bump', 'Crossing',
#        'Give_Way', 'Junction', 'No_Exit', 'Railway', 'Roundabout', 'Station',
#        'Stop', 'Traffic_Calming', 'Traffic_Signal', 'Turning_Loop',
#        'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
df['Weather_Timestamp'] = pd.to_datetime(df['Weather_Timestamp'], format='%Y-%m-%d %H:%M:%S')

# %%
df['day_of_week'] = df['Weather_Timestamp'].dt.dayofweek

# %%
df['weekend'] = df['day_of_week'].apply(lambda x: 1 if x>4 else 0)

# %%
sns.countplot(x='Severity',hue='weekend',data = df)
# Out:
# <AxesSubplot:xlabel='Severity', ylabel='count'>

# %%
sns.countplot(x='Severity',hue='day_of_week',data=df)
# Out:
# <AxesSubplot:xlabel='Severity', ylabel='count'>

# %%
df['Time'] = df['Weather_Timestamp'].dt.hour.apply(lambda x: 1 if x>18 or x<7 else 0)

# %%
sns.countplot(x='Severity',hue='Time',data = df)
# Out:
# <AxesSubplot:xlabel='Severity', ylabel='count'>

# %%
df = df.iloc[df[['TMC']].dropna().index]

# %%
(df.isnull().sum()/df.shape[0])*100
# Out:
# ID                         0.000000
# Source                     0.000000
# TMC                        0.000000
# Severity                   0.000000
# Start_Time                 0.000000
# End_Time                   0.000000
# Start_Lat                  0.000000
# Start_Lng                  0.000000
# End_Lat                  100.000000
# End_Lng                  100.000000
# Distance(mi)               0.000000
# Description                0.000040
# Number                    60.336378
# Street                     0.000000
# Side                       0.000000
# City                       0.002057
# County                     0.000000
# State                      0.000000
# Zipcode                    0.012506
# Country                    0.000000
# Timezone                   0.083144
# Airport_Code               0.166975
# Weather_Timestamp          1.120292
# Temperature(F)             1.654942
# Wind_Chill(F)             58.076793
# Humidity(%)                1.763300
# Pressure(in)               1.417853
# Visibility(mi)             1.976950
# Wind_Direction             1.431045
# Wind_Speed(mph)           13.885368
# Precipitation(in)         62.308003
# Weather_Condition          1.975095
# Amenity                    0.000000
# Bump                       0.000000
# Crossing                   0.000000
# Give_Way                   0.000000
# Junction                   0.000000
# No_Exit                    0.000000
# Railway                    0.000000
# Roundabout                 0.000000
# Station                    0.000000
# Stop                       0.000000
# Traffic_Calming            0.000000
# Traffic_Signal             0.000000
# Turning_Loop               0.000000
# Sunrise_Sunset             0.002178
# Civil_Twilight             0.002178
# Nautical_Twilight          0.002178
# Astronomical_Twilight      0.002178
# day_of_week                1.120292
# weekend                    0.000000
# Time                       0.000000
# dtype: float64

# %%
#sns.heatmap(df.isnull(),cmap = 'crest')

# %% [markdown]
# End_Lat, End_Lng, Number, Wind_Chill(F), Wind_Speed(mph), Precipitation(in), have more NaN values and it is difficult to interprate values for End_Lat, End_Lng, Number

# %%
df = df.drop(['End_Lat', 'End_Lng', 'Number'],axis = 1)

# %%
df['Start_Time'] = pd.to_datetime(df['Start_Time'], format = '%Y-%m-%d %H:%M:%S')
df['End_Time'] = pd.to_datetime(df['End_Time'], format = '%Y-%m-%d %H:%M:%S')

# %%
df['accident_time'] = df['End_Time'] - df['Start_Time']

# %%
accident_days = (df['accident_time'].dt.days.value_counts())

# %%
df.isnull().sum()
# Out:
# ID                             0
# Source                         0
# TMC                            0
# Severity                       0
# Start_Time                     0
# End_Time                       0
# Start_Lat                      0
# Start_Lng                      0
# Distance(mi)                   0
# Description                    1
# Street                         0
# Side                           0
# City                          51
# County                         0
# State                          0
# Zipcode                      310
# Country                        0
# Timezone                    2061
# Airport_Code                4139
# Weather_Timestamp          27770
# Temperature(F)             41023
# Wind_Chill(F)            1439618
# Humidity(%)                43709
# Pressure(in)               35146
# Visibility(mi)             49005
# Wind_Direction             35473
# Wind_Speed(mph)           344193
# Precipitation(in)        1544502
# Weather_Condition          48959
# Amenity                        0
# Bump                           0
# Crossing                       0
# Give_Way                       0
# Junction                       0
# No_Exit                        0
# Railway                        0
# Roundabout                     0
# Station                        0
# Stop                           0
# Traffic_Calming                0
# Traffic_Signal                 0
# Turning_Loop                   0
# Sunrise_Sunset                54
# Civil_Twilight                54
# Nautical_Twilight             54
# Astronomical_Twilight         54
# day_of_week                27770
# weekend                        0
# Time                           0
# accident_time                  0
# dtype: int64

# %%
df = df.iloc[df[['Weather_Timestamp']].dropna().index]

# %%
(df.isnull().sum()/df.shape[0])*100
# Out:
# ID                        0.000000
# Source                    0.000000
# TMC                       0.000000
# Severity                  0.000000
# Start_Time                0.000000
# End_Time                  0.000000
# Start_Lat                 0.000000
# Start_Lng                 0.000000
# Distance(mi)              0.000000
# Description               0.000041
# Street                    0.000000
# Side                      0.000000
# City                      0.002040
# County                    0.000000
# State                     0.000000
# Zipcode                   0.000000
# Country                   0.000000
# Timezone                  0.000000
# Airport_Code              0.000000
# Weather_Timestamp         0.000000
# Temperature(F)            0.540707
# Wind_Chill(F)            57.601810
# Humidity(%)               0.650293
# Pressure(in)              0.300932
# Visibility(mi)            0.866364
# Wind_Direction            0.314274
# Wind_Speed(mph)          12.909702
# Precipitation(in)        61.880959
# Weather_Condition         0.864487
# Amenity                   0.000000
# Bump                      0.000000
# Crossing                  0.000000
# Give_Way                  0.000000
# Junction                  0.000000
# No_Exit                   0.000000
# Railway                   0.000000
# Roundabout                0.000000
# Station                   0.000000
# Stop                      0.000000
# Traffic_Calming           0.000000
# Traffic_Signal            0.000000
# Turning_Loop              0.000000
# Sunrise_Sunset            0.002162
# Civil_Twilight            0.002162
# Nautical_Twilight         0.002162
# Astronomical_Twilight     0.002162
# day_of_week               0.000000
# weekend                   0.000000
# Time                      0.000000
# accident_time             0.000000
# dtype: float64

# %%
df['month'] = df['Weather_Timestamp'].dt.month

# %%
df['year'] = df['Weather_Timestamp'].dt.year

# %%
df['day'] = df['Weather_Timestamp'].dt.day

# %%
df[['Wind_Chill(F)']] = df[['Wind_Chill(F)']].interpolate()

# %%
df[['Temperature(F)']] = df[['Temperature(F)']].interpolate()

# %%
df.groupby('month').mean()[['Temperature(F)']]
# Out:
#        Temperature(F)
# month
# 1           43.936429
# 2           48.096902
# 3           53.266718
# 4           61.309840
# 5           69.572217
# 6           75.720241
# 7           80.091867
# 8           78.773867
# 9           74.680796
# 10          64.476433
# 11          53.651062
# 12          45.960336

# %%
df.isna().sum()
# Out:
# ID                             0
# Source                         0
# TMC                            0
# Severity                       0
# Start_Time                     0
# End_Time                       0
# Start_Lat                      0
# Start_Lng                      0
# Distance(mi)                   0
# Description                    1
# Street                         0
# Side                           0
# City                          50
# County                         0
# State                          0
# Zipcode                        0
# Country                        0
# Timezone                       0
# Airport_Code                   0
# Weather_Timestamp              0
# Temperature(F)                 0
# Wind_Chill(F)                  2
# Humidity(%)                15939
# Pressure(in)                7376
# Visibility(mi)             21235
# Wind_Direction              7703
# Wind_Speed(mph)           316423
# Precipitation(in)        1516732
# Weather_Condition          21189
# Amenity                        0
# Bump                           0
# Crossing                       0
# Give_Way                       0
# Junction                       0
# No_Exit                        0
# Railway                        0
# Roundabout                     0
# Station                        0
# Stop                           0
# Traffic_Calming                0
# Traffic_Signal                 0
# Turning_Loop                   0
# Sunrise_Sunset                53
# Civil_Twilight                53
# Nautical_Twilight             53
# Astronomical_Twilight         53
# day_of_week                    0
# weekend                        0
# Time                           0
# accident_time                  0
# month                          0
# year                           0
# day                            0
# dtype: int64

# %%
df[['Humidity(%)']] = df[['Humidity(%)']].interpolate()

# %%
df.groupby('month').mean()[['Humidity(%)']]
# Out:
#        Humidity(%)
# month
# 1        69.630671
# 2        70.283805
# 3        63.529419
# 4        61.871593
# 5        64.649479
# 6        63.105452
# 7        63.066155
# 8        66.060704
# 9        66.463726
# 10       67.156255
# 11       67.308909
# 12       69.336466

# %%
(df.isna().sum()/df.shape[0])*100
# Out:
# ID                        0.000000
# Source                    0.000000
# TMC                       0.000000
# Severity                  0.000000
# Start_Time                0.000000
# End_Time                  0.000000
# Start_Lat                 0.000000
# Start_Lng                 0.000000
# Distance(mi)              0.000000
# Description               0.000041
# Street                    0.000000
# Side                      0.000000
# City                      0.002040
# County                    0.000000
# State                     0.000000
# Zipcode                   0.000000
# Country                   0.000000
# Timezone                  0.000000
# Airport_Code              0.000000
# Weather_Timestamp         0.000000
# Temperature(F)            0.000000
# Wind_Chill(F)             0.000082
# Humidity(%)               0.000000
# Pressure(in)              0.300932
# Visibility(mi)            0.866364
# Wind_Direction            0.314274
# Wind_Speed(mph)          12.909702
# Precipitation(in)        61.880959
# Weather_Condition         0.864487
# Amenity                   0.000000
# Bump                      0.000000
# Crossing                  0.000000
# Give_Way                  0.000000
# Junction                  0.000000
# No_Exit                   0.000000
# Railway                   0.000000
# Roundabout                0.000000
# Station                   0.000000
# Stop                      0.000000
# Traffic_Calming           0.000000
# Traffic_Signal            0.000000
# Turning_Loop              0.000000
# Sunrise_Sunset            0.002162
# Civil_Twilight            0.002162
# Nautical_Twilight         0.002162
# Astronomical_Twilight     0.002162
# day_of_week               0.000000
# weekend                   0.000000
# Time                      0.000000
# accident_time             0.000000
# month                     0.000000
# year                      0.000000
# day                       0.000000
# dtype: float64

# %%
df.groupby('month').mean()[['Wind_Speed(mph)']]
# Out:
#        Wind_Speed(mph)
# month
# 1             8.575275
# 2             8.873334
# 3             9.338073
# 4             9.107780
# 5             8.416213
# 6             7.928185
# 7             7.548391
# 8             7.340925
# 9             7.555153
# 10            7.939995
# 11            7.816619
# 12            8.201241

# %%
df[['Wind_Speed(mph)']] = df[['Wind_Speed(mph)']].interpolate()
df[['Wind_Speed(mph)']] = df['Wind_Speed(mph)'].fillna(method = 'bfill')

# %%
df.groupby('month').mean()[['Wind_Speed(mph)']]
# Out:
#        Wind_Speed(mph)
# month
# 1             8.250224
# 2             8.556878
# 3             8.992067
# 4             8.899745
# 5             8.244503
# 6             7.778303
# 7             7.356962
# 8             7.130053
# 9             7.266796
# 10            7.632450
# 11            7.497557
# 12            7.889234

# %%
df.groupby('day').mean()[['Pressure(in)']]
# Out:
#      Pressure(in)
# day
# 1       29.825534
# 2       29.811703
# 3       29.763339
# 4       29.796402
# 5       29.812763
# 6       29.809499
# 7       29.841588
# 8       29.843452
# 9       29.816385
# 10      29.799320
# 11      29.822462
# 12      29.816533
# 13      29.822198
# 14      29.846910
# 15      29.813665
# 16      29.804750
# 17      29.788747
# 18      29.797502
# 19      29.811684
# 20      29.809508
# 21      29.814798
# 22      29.828646
# 23      29.808431
# 24      29.766898
# 25      29.791188
# 26      29.799224
# 27      29.829532
# 28      29.808157
# 29      29.790212
# 30      29.799329
# 31      29.818800

# %%
df[['Pressure(in)']] = df[['Pressure(in)']].replace(np.nan,df['Pressure(in)'].mean())

# %%
df.groupby('day').mean()[['Pressure(in)']]
# Out:
#      Pressure(in)
# day
# 1       29.825487
# 2       29.811699
# 3       29.763460
# 4       29.796435
# 5       29.812756
# 6       29.809501
# 7       29.841508
# 8       29.843346
# 9       29.816368
# 10      29.799345
# 11      29.822425
# 12      29.816512
# 13      29.822162
# 14      29.846778
# 15      29.813656
# 16      29.804768
# 17      29.788820
# 18      29.797543
# 19      29.811680
# 20      29.809511
# 21      29.814784
# 22      29.828597
# 23      29.808437
# 24      29.767017
# 25      29.791249
# 26      29.799257
# 27      29.829474
# 28      29.808163
# 29      29.790278
# 30      29.799357
# 31      29.818770

# %%
df[['Visibility(mi)']]
# Out:
#          Visibility(mi)
# 0                  10.0
# 1                  10.0
# 2                  10.0
# 3                   9.0
# 4                   6.0
# ...                 ...
# 2478813            10.0
# 2478814            10.0
# 2478815             6.0
# 2478816            10.0
# 2478817            10.0
#
# [2451048 rows x 1 columns]

# %%
df.isnull().sum()
# Out:
# ID                             0
# Source                         0
# TMC                            0
# Severity                       0
# Start_Time                     0
# End_Time                       0
# Start_Lat                      0
# Start_Lng                      0
# Distance(mi)                   0
# Description                    1
# Street                         0
# Side                           0
# City                          50
# County                         0
# State                          0
# Zipcode                        0
# Country                        0
# Timezone                       0
# Airport_Code                   0
# Weather_Timestamp              0
# Temperature(F)                 0
# Wind_Chill(F)                  2
# Humidity(%)                    0
# Pressure(in)                   0
# Visibility(mi)             21235
# Wind_Direction              7703
# Wind_Speed(mph)                0
# Precipitation(in)        1516732
# Weather_Condition          21189
# Amenity                        0
# Bump                           0
# Crossing                       0
# Give_Way                       0
# Junction                       0
# No_Exit                        0
# Railway                        0
# Roundabout                     0
# Station                        0
# Stop                           0
# Traffic_Calming                0
# Traffic_Signal                 0
# Turning_Loop                   0
# Sunrise_Sunset                53
# Civil_Twilight                53
# Nautical_Twilight             53
# Astronomical_Twilight         53
# day_of_week                    0
# weekend                        0
# Time                           0
# accident_time                  0
# month                          0
# year                           0
# day                            0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# ID                             0
# Source                         0
# TMC                            0
# Severity                       0
# Start_Time                     0
# End_Time                       0
# Start_Lat                      0
# Start_Lng                      0
# Distance(mi)                   0
# Description                    1
# Street                         0
# Side                           0
# City                          50
# County                         0
# State                          0
# Zipcode                        0
# Country                        0
# Timezone                       0
# Airport_Code                   0
# Weather_Timestamp              0
# Temperature(F)                 0
# Wind_Chill(F)                  2
# Humidity(%)                    0
# Pressure(in)                   0
# Visibility(mi)             21235
# Wind_Direction              7703
# Wind_Speed(mph)                0
# Precipitation(in)        1516732
# Weather_Condition          21189
# Amenity                        0
# Bump                           0
# Crossing                       0
# Give_Way                       0
# Junction                       0
# No_Exit                        0
# Railway                        0
# Roundabout                     0
# Station                        0
# Stop                           0
# Traffic_Calming                0
# Traffic_Signal                 0
# Turning_Loop                   0
# Sunrise_Sunset                53
# Civil_Twilight                53
# Nautical_Twilight             53
# Astronomical_Twilight         53
# day_of_week                    0
# weekend                        0
# Time                           0
# accident_time                  0
# month                          0
# year                           0
# day                            0
# dtype: int64

# %%
df = df.loc[df[['Wind_Direction']].dropna().index]

# %%
df.isnull().sum()
# Out:
# ID                             0
# Source                         0
# TMC                            0
# Severity                       0
# Start_Time                     0
# End_Time                       0
# Start_Lat                      0
# Start_Lng                      0
# Distance(mi)                   0
# Description                    1
# Street                         0
# Side                           0
# City                          50
# County                         0
# State                          0
# Zipcode                        0
# Country                        0
# Timezone                       0
# Airport_Code                   0
# Weather_Timestamp              0
# Temperature(F)                 0
# Wind_Chill(F)                  2
# Humidity(%)                    0
# Pressure(in)                   0
# Visibility(mi)             18373
# Wind_Direction                 0
# Wind_Speed(mph)                0
# Precipitation(in)        1516591
# Weather_Condition          18515
# Amenity                        0
# Bump                           0
# Crossing                       0
# Give_Way                       0
# Junction                       0
# No_Exit                        0
# Railway                        0
# Roundabout                     0
# Station                        0
# Stop                           0
# Traffic_Calming                0
# Traffic_Signal                 0
# Turning_Loop                   0
# Sunrise_Sunset                53
# Civil_Twilight                53
# Nautical_Twilight             53
# Astronomical_Twilight         53
# day_of_week                    0
# weekend                        0
# Time                           0
# accident_time                  0
# month                          0
# year                           0
# day                            0
# dtype: int64

# %%
df['Timezone'].unique()
# Out:
# array(['US/Eastern', 'US/Pacific', 'US/Central', 'US/Mountain'],
#       dtype=object)

# %%
#sns.heatmap(df.isnull(),cmap = 'inferno', yticklabels = False)

# %%
df = df.loc[df[['Weather_Condition']].dropna().index]

# %%
df
# Out:
#                 ID    Source    TMC  Severity          Start_Time  \
# 0              A-1  MapQuest  201.0         3 2016-02-08 05:46:00
# 1              A-2  MapQuest  201.0         2 2016-02-08 06:07:59
# 2              A-3  MapQuest  201.0         2 2016-02-08 06:49:27
# 3              A-4  MapQuest  201.0         3 2016-02-08 07:23:34
# 4              A-5  MapQuest  201.0         2 2016-02-08 07:39:07
# ...            ...       ...    ...       ...                 ...
# 2478813  A-2478854  MapQuest  201.0         3 2017-08-30 18:41:30
# 2478814  A-2478855  MapQuest  201.0         3 2017-08-30 18:59:02
# 2478815  A-2478856  MapQuest  201.0         3 2017-08-30 18:57:52
# 2478816  A-2478857  MapQuest  201.0         3 2017-08-30 19:49:01
# 2478817  A-2478858  MapQuest  201.0         2 2017-08-30 20:17:21
#
#                    End_Time  Start_Lat   Start_Lng  Distance(mi)  \
# 0       2016-02-08 11:00:00  39.865147  -84.058723          0.01
# 1       2016-02-08 06:37:59  39.928059  -82.831184          0.01
# 2       2016-02-08 07:19:27  39.063148  -84.032608          0.01
# 3       2016-02-08 07:53:34  39.747753  -84.205582          0.01
# 4       2016-02-08 08:09:07  39.627781  -84.188354          0.01
# ...                     ...        ...         ...           ...
# 2478813 2017-08-30 19:11:07  34.495808 -118.623932          0.00
# 2478814 2017-08-30 19:27:57  34.031322 -118.433723          0.00
# 2478815 2017-08-30 19:26:11  34.106785 -117.369102          0.00
# 2478816 2017-08-30 20:18:00  33.924686 -118.103981          0.00
# 2478817 2017-08-30 20:47:21  33.729469 -117.397354          0.00
#
#                                                Description  ...  \
# 0        Right lane blocked due to accident on I-70 Eas...  ...
# 1        Accident on Brice Rd at Tussing Rd. Expect del...  ...
# 2        Accident on OH-32 State Route 32 Westbound at ...  ...
# 3        Accident on I-75 Southbound at Exits 52 52B US...  ...
# 4        Accident on McEwen Rd at OH-725 Miamisburg Cen...  ...
# ...                                                    ...  ...
# 2478813  Accident on I-5 Southbound at Forest Rte-7N09 ...  ...
# 2478814  Left lane closed due to accident on I-10 at Na...  ...
# 2478815      Accident on Olive Ave at CA-66 Foothill Blvd.  ...
# 2478816  #1 lane blocked due to accident on I-605 North...  ...
# 2478817  Accident on Temescal Canyon Rd Eastbound in La...  ...
#
#         Civil_Twilight Nautical_Twilight Astronomical_Twilight day_of_week  \
# 0                Night             Night                 Night         0.0
# 1                Night             Night                   Day         0.0
# 2                Night               Day                   Day         0.0
# 3                  Day               Day                   Day         0.0
# 4                  Day               Day                   Day         0.0
# ...                ...               ...                   ...         ...
# 2478813            Day               Day                   Day         2.0
# 2478814            Day               Day                   Day         2.0
# 2478815            Day               Day                   Day         2.0
# 2478816          Night               Day                   Day         2.0
# 2478817          Night             Night                   Day         2.0
#
#         weekend Time   accident_time month  year day
# 0             0    1 0 days 05:14:00     2  2016   8
# 1             0    1 0 days 00:30:00     2  2016   8
# 2             0    1 0 days 00:30:00     2  2016   8
# 3             0    0 0 days 00:30:00     2  2016   8
# 4             0    0 0 days 00:30:00     2  2016   8
# ...         ...  ...             ...   ...   ...  ..
# 2478813       0    0 0 days 00:29:37     8  2017  30
# 2478814       0    0 0 days 00:28:55     8  2017  30
# 2478815       0    0 0 days 00:28:19     8  2017  30
# 2478816       0    1 0 days 00:28:59     8  2017  30
# 2478817       0    1 0 days 00:30:00     8  2017  30
#
# [2424830 rows x 53 columns]

# %%
df.isnull().sum()
# Out:
# ID                             0
# Source                         0
# TMC                            0
# Severity                       0
# Start_Time                     0
# End_Time                       0
# Start_Lat                      0
# Start_Lng                      0
# Distance(mi)                   0
# Description                    1
# Street                         0
# Side                           0
# City                          48
# County                         0
# State                          0
# Zipcode                        0
# Country                        0
# Timezone                       0
# Airport_Code                   0
# Weather_Timestamp              0
# Temperature(F)                 0
# Wind_Chill(F)                  2
# Humidity(%)                    0
# Pressure(in)                   0
# Visibility(mi)              5316
# Wind_Direction                 0
# Wind_Speed(mph)                0
# Precipitation(in)        1500129
# Weather_Condition              0
# Amenity                        0
# Bump                           0
# Crossing                       0
# Give_Way                       0
# Junction                       0
# No_Exit                        0
# Railway                        0
# Roundabout                     0
# Station                        0
# Stop                           0
# Traffic_Calming                0
# Traffic_Signal                 0
# Turning_Loop                   0
# Sunrise_Sunset                51
# Civil_Twilight                51
# Nautical_Twilight             51
# Astronomical_Twilight         51
# day_of_week                    0
# weekend                        0
# Time                           0
# accident_time                  0
# month                          0
# year                           0
# day                            0
# dtype: int64

# %%
df = df.drop(['ID','Source','Description','Street','City','County','Airport_Code','Precipitation(in)','Civil_Twilight','Nautical_Twilight','Astronomical_Twilight'],axis=1)

# %%
df.isnull().sum()
# Out:
# TMC                     0
# Severity                0
# Start_Time              0
# End_Time                0
# Start_Lat               0
# Start_Lng               0
# Distance(mi)            0
# Side                    0
# State                   0
# Zipcode                 0
# Country                 0
# Timezone                0
# Weather_Timestamp       0
# Temperature(F)          0
# Wind_Chill(F)           2
# Humidity(%)             0
# Pressure(in)            0
# Visibility(mi)       5316
# Wind_Direction          0
# Wind_Speed(mph)         0
# Weather_Condition       0
# Amenity                 0
# Bump                    0
# Crossing                0
# Give_Way                0
# Junction                0
# No_Exit                 0
# Railway                 0
# Roundabout              0
# Station                 0
# Stop                    0
# Traffic_Calming         0
# Traffic_Signal          0
# Turning_Loop            0
# Sunrise_Sunset         51
# day_of_week             0
# weekend                 0
# Time                    0
# accident_time           0
# month                   0
# year                    0
# day                     0
# dtype: int64

# %%
df[['Zipcode']] = df['Zipcode'].apply(lambda x: x.split('-')[0]).astype('int64')

# %%
df[['Zipcode']]
# Out:
#          Zipcode
# 0          45424
# 1          43068
# 2          45176
# 3          45417
# 4          45459
# ...          ...
# 2478813    91384
# 2478814    90064
# 2478815    92376
# 2478816    90650
# 2478817    92530
#
# [2424830 rows x 1 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()

# %%
s= pd.DataFrame(encoder.fit_transform(df['Weather_Condition']))

# %%
df['Weather_Condition'].unique().shape
# Out:
# (120,)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2424830 entries, 0 to 2478817
# Data columns (total 42 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   TMC                float64
#  1   Severity           int64
#  2   Start_Time         datetime64[ns]
#  3   End_Time           datetime64[ns]
#  4   Start_Lat          float64
#  5   Start_Lng          float64
#  6   Distance(mi)       float64
#  7   Side               object
#  8   State              object
#  9   Zipcode            int64
#  10  Country            object
#  11  Timezone           object
#  12  Weather_Timestamp  datetime64[ns]
#  13  Temperature(F)     float64
#  14  Wind_Chill(F)      float64
#  15  Humidity(%)        float64
#  16  Pressure(in)       float64
#  17  Visibility(mi)     float64
#  18  Wind_Direction     object
#  19  Wind_Speed(mph)    float64
#  20  Weather_Condition  object
#  21  Amenity            bool
#  22  Bump               bool
#  23  Crossing           bool
#  24  Give_Way           bool
#  25  Junction           bool
#  26  No_Exit            bool
#  27  Railway            bool
#  28  Roundabout         bool
#  29  Station            bool
#  30  Stop               bool
#  31  Traffic_Calming    bool
#  32  Traffic_Signal     bool
#  33  Turning_Loop       bool
#  34  Sunrise_Sunset     object
#  35  day_of_week        float64
#  36  weekend            int64
#  37  Time               int64
#  38  accident_time      timedelta64[ns]
#  39  month              int64
#  40  year               int64
#  41  day                int64
# dtypes: bool(13), datetime64[ns](3), float64(11), int64(7), object(7), timedelta64[ns](1)
# memory usage: 585.1+ MB

# %%
sns.boxplot(x=df[['Humidity(%)      
']])
# Out:
#   File "<ipython-input-65-2c5ce68ff98f>", line 1
#     sns.boxplot(x=df[['Humidity(%)
#                                         ^
# SyntaxError: EOL while scanning string literal
