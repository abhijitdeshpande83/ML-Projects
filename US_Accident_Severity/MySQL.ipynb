# %%
import pandas as pd
import numpy as np

# %%
import mysql.connector

# %%
#%time df = pd.read_csv('/Users/abhijitdeshpande/Downloads/Chicago_Public.csv')

# %%
df.shape
# Out:
# (566, 79)

# %%
conn = mysql.connector.connect(
        host='localhost',
        user='root',
        passwd='Abhi8855',
        database='crime'
)

# %%
cursor = conn.cursor()

# %%
cursor.execute('show databases')

# %%
for i in cursor:
    print(i)
# Out:
# ('crime',)
# ('information_schema',)
# ('mysql',)
# ('performance_schema',)
# ('school',)
# ('sys',)

# %%
cursor.execute('select count(*) from crime')

# %%
cursor.fetchall()
# Out:
# [(6679036,)]

# %%
cursor.execute('select * from crime')

# %%
cursor.fetchall()
# Out:
# [(10224738,
#   'HY411648',
#   '09/05/2015 01:30:00 PM',
#   '043XX S WOOD ST',
#   '0486',
#   'BATTERY',
#   'DOMESTIC BATTERY SIMPLE',
#   'RESIDENCE',
#   'false',
#   'true',
#   '0924',
#   '009',
#   12,
#   61,
#   '08B',
#   '1165074',
#   '1875917',
#   2015,
#   '02/10/2018 03:50:01 PM',
#   '41.815117282',
#   '-87.669999562',
#   '(41.815117282, -87.669999562)'),
#  (10224739,
#   'HY411615',
#   '09/04/2015 11:30:00 AM',
#   '008XX N CENTRAL AVE',
#   '0870',
#   'THEFT',
#   'POCKET-PICKING',
#   'CTA BUS',
#   'false',
#   'false',
#   '1511',
#   '015',
#   29,
#   25,
#   '06',
#   '1138875',
#   '1904869',
#   2015,
#   '02/10/2018 03:50:01 PM',
#   '41.895080471',
#   '-87.765400451',
#   '(41.895080471, -87.765400451)'),
#  (11646166,
#   'JC213529',
#   '09/01/2018 12:01:00 AM',
#   '082XX S INGLESIDE AVE',
#   '0810',
#   'THEFT',
#   'OVER $500',
#   'RESIDENCE',
#   'false',
#   'true',
#   '0631',
#   '006',
#   8,
#   44,
#   '06',
#   '',
#   '',
# ...
